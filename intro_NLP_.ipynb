# %%
import nltk
nltk.download('book')
from  nltk.book import *
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# ...

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text8
# Out:
# <Text: Personals Corpus>

# %%
text3
# Out:
# <Text: The Book of Genesis>

# %%
text9.tokens
# Out:
# ['[',
#  'The',
#  'Man',
#  'Who',
#  'Was',
#  'Thursday',
#  'by',
#  'G',
#  '.',
#  'K',
#  '.',
#  'Chesterton',
#  '1908',
#  ']',
#  'To',
#  'Edmund',
#  'Clerihew',
#  'Bentley',
#  'A',
#  'cloud',
#  'was',
#  'on',
#  'the',
#  'mind',
#  'of',
#  'men',
#  ',',
#  'and',
#  'wailing',
#  'went',
#  'the',
#  'weather',
#  ',',
#  'Yea',
#  ',',
#  'a',
#  'sick',
#  'cloud',
#  'upon',
#  'the',
#  'soul',
#  'when',
#  'we',
#  'were',
#  'boys',
#  'together',
#  '.',
#  'Science',
#  'announced',
#  'nonentity',
#  'and',
#  'art',
#  'admired',
#  'decay',
#  ';',
#  'The',
#  'world',
#  'was',
#  'old',
#  'and',
#  'ended',
#  ':',
#  'but',
#  'you',
#  'and',
#  'I',
#  'were',
#  'gay',
#  ';',
#  'Round',
#  'us',
#  'in',
#  'antic',
#  'order',
#  'their',
#  'crippled',
#  'vices',
#  'came',
#  '--',
#  'Lust',
#  'that',
#  'had',
#  'lost',
#  'its',
#  'laughter',
#  ',',
#  'fear',
#  'that',
#  'had',
#  'lost',
#  'its',
#  'shame',
#  '.',
# ...

# %%
len(text9)
# Out:
# 69213

# %%
### riqueza lexica relacion entre la cantidad de palabras unicas/cantidad de pa
#labras totales

R_L=len(set(text9))/len(text9)
print(R_L)
print(len(set(text9)))
# Out:
# 0.0983485761345412
# 6807

# %%
F_word=FreqDist(text9)
F_word.most_common(10)
# Out:
# [(',', 3488),
#  ('the', 3291),
#  ('.', 2717),
#  ('a', 1713),
#  ('of', 1710),
#  ('and', 1568),
#  ('"', 1336),
#  ('to', 1045),
#  ('in', 888),
#  ('I', 885)]

# %%
import matplotlib.pyplot as plt
F_word.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
import re
texto_para_toke="Bajo ñ esta panorama, '???        '' ' ?ayer el centro de estudio económico Fedesarrollo presentó un análisis detallado del sistema de salud de Colombia 1. Estructurar redes integrales e integradas a nivel regional."

# %%
tokens1=re.split(r'[\W\t\n]+',texto_para_toke)
print((tokens1))
# Out:
# ['Bajo', 'ñ', 'esta', 'panorama', 'ayer', 'el', 'centro', 'de', 'estudio', 'económico', 'Fedesarrollo', 'presentó', 'un', 'análisis', 'detallado', 'del', 'sistema', 'de', 'salud', 'de', 'Colombia', '1', 'Estructurar', 'redes', 'integrales', 'e', 'integradas', 'a', 'nivel', 'regional', '']

# %%
bigramas=bigrams(text9)
(FreqDist(bigramas)).most_common(10)
# Out:
# [(('.', '"'), 583),
#  ((',', 'and'), 569),
#  (('of', 'the'), 413),
#  ((',', '"'), 286),
#  ((',"', 'said'), 272),
#  (('in', 'the'), 226),
#  (("'", 's'), 224),
#  (('.', 'He'), 218),
#  (('."', '"'), 210),
#  (('.', 'The'), 205)]

# %%
from nltk import ngrams
trigramas=(ngrams(text1,3))
Fre_trigramas=FreqDist(trigramas)
print((Fre_trigramas))
import matplotlib.pyplot as plt
Fre_trigramas.plot(10)
# Out:
# <FreqDist with 212844 samples and 260817 outcomes>
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
bigramas=(ngrams(text1,4))
Fre_trigramas=FreqDist(bigramas)
print((Fre_trigramas))
import matplotlib.pyplot as plt
Fre_trigramas.plot(10)
# Out:
# <FreqDist with 118748 samples and 260818 outcomes>
# <Axes: xlabel='Samples', ylabel='Counts'>
